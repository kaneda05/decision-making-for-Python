# %%
from calc_payiff_table import calc_payoff_table

# %%
calc_payoff_table(100, 600, 0.2, 5000, 10000, 5000)
# Out:
#         0台    1台    2台
# 好調 -100.0  300.0  700.0
# 不調 -100.0  300.0 -300.0

# %%
for i in range(1, 5):
    print(calc_payoff_table(100, 600, 0.2*i, 5000, 10000, 5000))
# Out:
#         0台    1台    2台
# 好調 -100.0  300.0  700.0
# 不調 -100.0  300.0 -300.0
#         0台     1台     2台
# 好調 -100.0  1300.0  2700.0
# 不調 -100.0  1300.0   700.0
#         0台     1台     2台
# 好調 -100.0  2300.0  4700.0
# 不調 -100.0  2300.0  1700.0
#         0台     1台     2台
# 好調 -100.0  3300.0  6700.0
# 不調 -100.0  3300.0  2700.0

# %%
for i in range(1, 5):
    print(calc_payoff_table(100, 600, 0.2*i, 5000, 10000, 5000)['2台'])
# Out:
# 好調    700.0
# 不調   -300.0
# Name: 2台, dtype: float64
# 好調    2700.0
# 不調     700.0
# Name: 2台, dtype: float64
# 好調    4700.0
# 不調    1700.0
# Name: 2台, dtype: float64
# 好調    6700.0
# 不調    2700.0
# Name: 2台, dtype: float64

# %%
import matplotlib.pyplot as plt
for i in range(1, 15):
    plt.scatter(calc_payoff_table(100, 600, 0.2*i, 5000, 10000, 5000)['2台']["好調"],calc_payoff_table(100, 600, 0.2*i, 5000, 10000, 5000)['2台']["不調"])

# %%
import matplotlib.pyplot as plt
for i in range(1, 100):
    plt.scatter(calc_payoff_table(100//i, 600//i, 0.2, 5000//i, 10000//i, 5000//i)['2台']["好調"],calc_payoff_table(100//i, 600//i, 0.2, 5000//i, 10000//i, 5000//i)['1台']["好調"])

# %%
for i in range(1, 100):
    plt.scatter(calc_payoff_table(100//i, 600, 0.2*i, 5000//i, 10000//i, 5000//i)['1台']["好調"],calc_payoff_table(100//i, 600, 0.2*i, 5000//i, 10000//i, 5000//i)['1台']["不調"])

# %%
for i in range(1, 100):
    plt.scatter(calc_payoff_table(100//i, 600//i, 0.2*i, 5000//i, 10000//i, 5000//i)['2台']["好調"],calc_payoff_table(100//i, 600//i, 0.2*i, 5000//i, 10000//i, 5000//i)['2台']["不調"])

# %%
for i in range(1, 100):
    plt.scatter(calc_payoff_table(100//i, 600, 0.2*i, 5000//i, 10000//i, 5000//i)['1台']["好調"],calc_payoff_table(100//i, 600, 0.2*i, 5000//i, 10000//i, 5000//i)['2台']["好調"])

# %%
for i in range(1, 100):
    plt.scatter(calc_payoff_table(100//i, 600, 0.2*i, 5000//i, 10000//i, 5000//i)['1台']["好調"],calc_payoff_table(100//i, 600, 0.2*i, 5000//i, 10000//i, 5000//i)['2台']["好調"])
